# %% [markdown]
# # Методы сбора и обработки данных из сети Интернет
# ## Урок 1. Основы клиент-серверного взаимодействия. Работа с API
# ### Задача№1
#
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.
# ***

# %%
import requests
import time
import json

# %%
url = 'https://api.github.com/users/DLSchool/repos'
repos = requests.get(url)
print(repos.text)
# Out:
# [{"id":146176390,"node_id":"MDEwOlJlcG9zaXRvcnkxNDYxNzYzOTA=","name":"deep-learning-school","full_name":"DLSchool/deep-learning-school","private":false,"owner":{"login":"DLSchool","id":41927172,"node_id":"MDEyOk9yZ2FuaXphdGlvbjQxOTI3MTcy","avatar_url":"https://avatars.githubusercontent.com/u/41927172?v=4","gravatar_id":"","url":"https://api.github.com/users/DLSchool","html_url":"https://github.com/DLSchool","followers_url":"https://api.github.com/users/DLSchool/followers","following_url":"https://api.github.com/users/DLSchool/following{/other_user}","gists_url":"https://api.github.com/users/DLSchool/gists{/gist_id}","starred_url":"https://api.github.com/users/DLSchool/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/DLSchool/subscriptions","organizations_url":"https://api.github.com/users/DLSchool/orgs","repos_url":"https://api.github.com/users/DLSchool/repos","events_url":"https://api.github.com/users/DLSchool/events{/privacy}","received_events_url":"https:/
# ...

# %%
with open('repos.json', 'w') as f:
    json.dump(repos.json(), f)

# %% [markdown]
# ### Задача№2
#
# Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
# ***

# %%
import requests
import json

app_id = 17090750
vk_version = '5.131'
auth_url = f'https://oauth.vk.com/authorize?client_id={app_id}&display=page&redirect_uri=https://oauth.vk.com/blank.html&scope=friends&response_type=token&v={vk_version}';
access_token = 'vk1.a.5rtTgDT6Xd2b1Vpg0wKoSs7PZCgDWNPdYjsAhGjeDTnqGFC6JhqvPJn7RHXS6yZViF3arF_GW9vxFl8eZD0tlsSYrOR9tqDMZAjY4cI8iY8IKTTW1bCh3bMR5yb3c9liqtyzVI2xIAwFUT66BJAbuLBtvw0AflHdw7aD2HocRdde0F3YZVQtys8NSZI-qZOk'

response = requests.get(f'https://api.vk.com/method/groups.get?extended=1&access_token={access_token}&v={vk_version}')
response_json = response.json()
with open('task02_response.json', 'w') as file:
    json.dump(response_json, file)

print('\nСписок сообществ, на которые вы подписаны')
for group in response_json['response']['items']:
    print(f"{group['name']}")
# Out:
# Список сообществ, на которые вы подписаны
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 15>()
#      12     json.dump(response_json, file)
#      14 print('\nСписок сообществ, на которые вы подписаны')
# ---> 15 for group in response_json['response']['items']:
#      16     print(f"{group['name']}")
#
# KeyError: 'response'
